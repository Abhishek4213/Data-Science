# %%
#### section A

# %%
list=[1,2,3,4,5]
list
# Out:
# [1, 2, 3, 4, 5]

# %%
list.append(10)
list
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
list.extend([25,30])
list
# Out:
# [1, 2, 3, 4, 5, 10, 25, 30]

# %%
list.insert(4,22)
list
# Out:
# [1, 2, 3, 4, 22, 5, 10, 25, 30]

# %%
list.remove(22)
list
# Out:
# [1, 2, 3, 4, 5, 10, 25, 30]

# %%
list.pop()
list
# Out:
# [1, 2, 3, 4, 5, 10, 25]

# %%
list.clear()
list
# Out:
# []

# %%
list=[1,2,3,4,5,10,25]
list
# Out:
# [1, 2, 3, 4, 5, 10, 25]

# %%
list.index(2)
# Out:
# 1

# %%
list.append(5)
list
# Out:
# [1, 2, 3, 4, 5, 10, 25, 5]

# %%
list.count(5)
# Out:
# 2

# %%
list
# Out:
# [1, 2, 3, 4, 5, 10, 25, 5]

# %%
list.sort()
list
# Out:
# [1, 2, 3, 4, 5, 5, 10, 25]

# %%
list.reverse()
list
# Out:
# [25, 10, 5, 5, 4, 3, 2, 1]

# %%
### tuple

# %%
s=('Abhishek','Adhul','Aswin')
s
# Out:
# ('Abhishek', 'Adhul', 'Aswin')

# %%
s[2]=('Aatlee')
s[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 s[2]=('Aatlee')
#       2 s[2]
#
# TypeError: 'tuple' object does not support item assignment

# %%
#### tuple can't modify,if it modify we have to change the tuple into list then we can easily change the name .

# %%
set={1,2,3,3,3,4,5}
set
# Out:
# {1, 2, 3, 4, 5}

# %%
### in set the duplicates be vanished while print,beacuse duplicates cannot be form in the set

# %%
dict1={'Name': ['Abhishek','Adhul','Aswin'],'Age':[22,22,21],'City':['Banglore','Kerala','Kerala']}
dict1
# Out:
# {'Name': ['Abhishek', 'Adhul', 'Aswin'],
#  'Age': [22, 22, 21],
#  'City': ['Banglore', 'Kerala', 'Kerala']}

# %%
dict1['Age']=25,22,21

# %%
dict1
# Out:
# {'Name': ['Abhishek', 'Adhul', 'Aswin'],
#  'Age': (25, 22, 21),
#  'City': ['Banglore', 'Kerala', 'Kerala']}

# %%
dict1.setdefault('email',['aaa.com','bbb.com','ccc.com'])
# Out:
# ['aaa.com', 'bbb.com', 'ccc.com']

# %%
dict1
# Out:
# {'Name': ['Abhishek', 'Adhul', 'Aswin'],
#  'Age': (25, 22, 21),
#  'City': ['Banglore', 'Kerala', 'Kerala'],
#  'email': ['aaa.com', 'bbb.com', 'ccc.com']}

# %%
n=int(input("enter the age"))
age=18
if(Age<=18):
    print(" Not eligible for vote")
else:
    print("Eligible for vote")
# Out:
# enter the age 18
#  Not eligible for vote

# %%
n=int(input("enter the mark"))
if(n>90):
    print("A")
elif(n>75 or n>89):
    print("B")
elif(n>50 or n>74):
    print("C")
elif(n<50):
    print("Fail")
# Out:
# enter the mark 80
# B

# %%
n=int(input("enter the number"))
if(n>0):
    print("it is positive number")
elif(n>0 and n%2==0):
    print("it is positive number and even number")
elif(n<0):
    print("it is negative number")
elif(n==0):
    print("it is zero")
# Out:
# enter the number 0
# it is zero

# %%
#### section B

# %%
import numpy as np
import pandas as pd

# %%
np.array(5)
# Out:
# array(5)

# %%
one_dim=np.array([1,2,3,4,5])
one_dim
# Out:
# array([1, 2, 3, 4, 5])

# %%
two_dim=[2,3]
two_dim
# Out:
# [2, 3]

# %%
two_dim=np.array([[10,20,30],[40,50,60]])
two_dim
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
a=np.array(np.random.randint(0,100,16)).reshape(4,4)
a
# Out:
# array([[87, 19, 38, 65],
#        [16, 45, 70, 16],
#        [10, 89, 19, 66],
#        [22, 79, 43, 31]])

# %%
s=np.array(np.random.randint(0,100,9).reshape(3,3))
s
# Out:
# array([[15, 95, 75],
#        [64,  5, 20],
#        [18, 72, 47]])

# %%
df=pd.DataFrame(s,columns=('A','B','C'))

# %%
df
# Out:
#     A   B   C
# 0  15  95  75
# 1  64   5  20
# 2  18  72  47

# %%
##### section c

# %%
dict={'Name': ['Abhi','Arun','Azi','Anu','Ansi','Amal','Aswin','Adhul','Athu','Aatlee'],
     'Age': [20,21,22,26,22,22,25,45,67,75],
     'City':['Banglore','Kerala','Goa','Kerala','Mumbai','Chennai','NorthEast','Banglore','Goa','Mumbai'],
       'Salary':[10000,20000,30000,45000,50000,55000,60000,50000,60000,89999] }

# %%
print(dict)
# Out:
# {'Name': ['Abhi', 'Arun', 'Azi', 'Anu', 'Ansi', 'Amal', 'Aswin', 'Adhul', 'Athu', 'Aatlee'], 'Age': [20, 21, 22, 26, 22, 22, 25, 45, 67, 75], 'City': ['Banglore', 'Kerala', 'Goa', 'Kerala', 'Mumbai', 'Chennai', 'NorthEast', 'Banglore', 'Goa', 'Mumbai'], 'Salary': [10000, 20000, 30000, 45000, 50000, 55000, 60000, 50000, 60000, 89999]}

# %%
df1=pd.DataFrame(dict)

# %%
df1
# Out:
#      Name  Age       City  Salary
# 0    Abhi   20   Banglore   10000
# 1    Arun   21     Kerala   20000
# 2     Azi   22        Goa   30000
# 3     Anu   26     Kerala   45000
# 4    Ansi   22     Mumbai   50000
# 5    Amal   22    Chennai   55000
# 6   Aswin   25  NorthEast   60000
# 7   Adhul   45   Banglore   50000
# 8    Athu   67        Goa   60000
# 9  Aatlee   75     Mumbai   89999

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   City    10 non-null     object
#  3   Salary  10 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df1.describe()
# Out:
#              Age        Salary
# count  10.000000     10.000000
# mean   34.500000  46999.900000
# std    20.630344  22754.520921
# min    20.000000  10000.000000
# 25%    22.000000  33750.000000
# 50%    23.500000  50000.000000
# 75%    40.250000  58750.000000
# max    75.000000  89999.000000

# %%
df1.iloc[:,[0,2]]
# Out:
#      Name       City
# 0    Abhi   Banglore
# 1    Arun     Kerala
# 2     Azi        Goa
# 3     Anu     Kerala
# 4    Ansi     Mumbai
# 5    Amal    Chennai
# 6   Aswin  NorthEast
# 7   Adhul   Banglore
# 8    Athu        Goa
# 9  Aatlee     Mumbai

# %%
df1.drop(columns=['City'])
# Out:
#      Name  Age  Salary
# 0    Abhi   20   10000
# 1    Arun   21   20000
# 2     Azi   22   30000
# 3     Anu   26   45000
# 4    Ansi   22   50000
# 5    Amal   22   55000
# 6   Aswin   25   60000
# 7   Adhul   45   50000
# 8    Athu   67   60000
# 9  Aatlee   75   89999

# %%
df1
# Out:
#      Name  Age       City  Salary
# 0    Abhi   20   Banglore   10000
# 1    Arun   21     Kerala   20000
# 2     Azi   22        Goa   30000
# 3     Anu   26     Kerala   45000
# 4    Ansi   22     Mumbai   50000
# 5    Amal   22    Chennai   55000
# 6   Aswin   25  NorthEast   60000
# 7   Adhul   45   Banglore   50000
# 8    Athu   67        Goa   60000
# 9  Aatlee   75     Mumbai   89999

# %%
df1.isnull().sum()
# Out:
# Name      0
# Age       0
# City      0
# Salary    0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0
